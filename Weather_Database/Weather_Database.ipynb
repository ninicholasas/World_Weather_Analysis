# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 752

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Sacramento"
city_weather = requests.get(city_url)
city_weather.text
# Out:
# '{"coord":{"lon":-121.3177,"lat":38.4666},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}],"base":"stations","main":{"temp":48.81,"feels_like":43.74,"temp_min":46.26,"temp_max":51.04,"pressure":1017,"humidity":86},"visibility":10000,"wind":{"speed":12.66,"deg":140},"clouds":{"all":75},"dt":1673419825,"sys":{"type":2,"id":2002655,"country":"US","sunrise":1673364146,"sunset":1673398959},"timezone":-28800,"id":5389519,"name":"Sacramento","cod":200}'

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print('Beginning Data Retrieval')
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if(i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_weather_description = city_weather['weather'][0]['description']
        
            
        # Append the city information into the city_data list
        city_data.append(
        {
            'City': city,
            'Lat': city_lat,
            'Lng': city_lng,
            'Max Temp': city_max_temp,
            'Humidity': city_humidity,
            'Cloudiness': city_clouds,
            'Wind Speed': city_wind,
            'Current Description': city_weather_description,
            'Country': city_country     
        })
    # If an error is experienced, skip the city
    except:
        print('City not found. Skipping...')
        pass

# Indicate that the Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | biak
# Processing Record 2 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | rawson
# Processing Record 6 of Set 1 | whitehorse
# Processing Record 7 of Set 1 | dikson
# Processing Record 8 of Set 1 | bathurst
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | ixtapa
# Processing Record 11 of Set 1 | salalah
# Processing Record 12 of Set 1 | avarua
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | batagay-alyta
# Processing Record 15 of Set 1 | georgetown
# Processing Record 16 of Set 1 | osmena
# Processing Record 17 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 1 | westport
# Processing Record 19 of Set 1 | mehamn
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | taltal
# Processing Record 22 of Set 1 | along
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 25 of Set 1 | iqaluit
# Processing Record 26 of Set 1 | alofi
# Processing Record 27 of Set 1 | bushehr
# Processing Record 28 of Set 1 | mount isa
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | jalu
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | hovd
# Processing Record 34 of Set 1 | radomsko
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | saskylakh
# Processing Record 37 of Set 1 | tutoia
# Processing Record 38 of Set 1 | codrington
# Processing Record 39 of Set 1 | sarangani
# Processing Record 40 of Set 1 | talnakh
# Processing Record 41 of Set 1 | hokitika
# Processing Record 42 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 1 | chimichagua
# Processing Record 44 of Set 1 | praia da vitoria
# Processing Record 45 of Set 1 | new norfolk
# Processing Record 46 of Set 1 | ust-kuyga
# Processing Record 47 of Set 1 | conakry
# Processing Record 48 of Set 1 | ust-maya
# Processing Record 49 of Set 1 | cap malheureux
# Processing Record 50 of Set 1 | leningradskiy
# Processing Record 1 of Set 2 | victoria
# Processing Record 2 of Set 2 | saint-pierre
# Processing Record 3 of Set 2 | vao
# Processing Record 4 of Set 2 | airai
# Processing Record 5 of Set 2 | beringovskiy
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | saldanha
# Processing Record 8 of Set 2 | middle island
# Processing Record 9 of Set 2 | carnarvon
# Processing Record 10 of Set 2 | lavrentiya
# Processing Record 11 of Set 2 | wollongong
# Processing Record 12 of Set 2 | gao
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | ilulissat
# Processing Record 15 of Set 2 | santa lucia
# Processing Record 16 of Set 2 | hilo
# Processing Record 17 of Set 2 | puerto escondido
# Processing Record 18 of Set 2 | busselton
# Processing Record 19 of Set 2 | tuktoyaktuk
# Processing Record 20 of Set 2 | provideniya
# Processing Record 21 of Set 2 | lebu
# Processing Record 22 of Set 2 | tasiilaq
# Processing Record 23 of Set 2 | vaini
# Processing Record 24 of Set 2 | arraial do cabo
# Processing Record 25 of Set 2 | puerto ayora
# Processing Record 26 of Set 2 | diapaga
# Processing Record 27 of Set 2 | adrar
# Processing Record 28 of Set 2 | cherskiy
# Processing Record 29 of Set 2 | qaanaaq
# Processing Record 30 of Set 2 | torbay
# Processing Record 31 of Set 2 | samaipata
# Processing Record 32 of Set 2 | bansang
# Processing Record 33 of Set 2 | mildura
# Processing Record 34 of Set 2 | kaitangata
# Processing Record 35 of Set 2 | aliwal north
# Processing Record 36 of Set 2 | gwadar
# Processing Record 37 of Set 2 | tokur
# Processing Record 38 of Set 2 | castanos
# Processing Record 39 of Set 2 | hasaki
# Processing Record 40 of Set 2 | fortuna
# Processing Record 41 of Set 2 | makakilo city
# Processing Record 42 of Set 2 | teseney
# Processing Record 43 of Set 2 | george town
# Processing Record 44 of Set 2 | nikolskoye
# Processing Record 45 of Set 2 | severo-kurilsk
# Processing Record 46 of Set 2 | hobart
# Processing Record 47 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 48 of Set 2 | asau
# Processing Record 49 of Set 2 | eltham
# Processing Record 50 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 3 | ostrovnoy
# Processing Record 2 of Set 3 | lamar
# Processing Record 3 of Set 3 | souillac
# Processing Record 4 of Set 3 | surt
# Processing Record 5 of Set 3 | comodoro rivadavia
# Processing Record 6 of Set 3 | kavieng
# Processing Record 7 of Set 3 | mataura
# Processing Record 8 of Set 3 | barcelona
# Processing Record 9 of Set 3 | dunedin
# Processing Record 10 of Set 3 | hobyo
# Processing Record 11 of Set 3 | vigrestad
# Processing Record 12 of Set 3 | saint george
# Processing Record 13 of Set 3 | port alfred
# Processing Record 14 of Set 3 | arlit
# Processing Record 15 of Set 3 | clyde river
# Processing Record 16 of Set 3 | pevek
# Processing Record 17 of Set 3 | faanui
# Processing Record 18 of Set 3 | esperance
# Processing Record 19 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 3 | gat
# Processing Record 21 of Set 3 | nanakuli
# Processing Record 22 of Set 3 | cayenne
# Processing Record 23 of Set 3 | kapaa
# Processing Record 24 of Set 3 | lompoc
# Processing Record 25 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 3 | butaritari
# Processing Record 27 of Set 3 | castro
# Processing Record 28 of Set 3 | shunyi
# Processing Record 29 of Set 3 | tiksi
# Processing Record 30 of Set 3 | raton
# Processing Record 31 of Set 3 | dombarovskiy
# Processing Record 32 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 3 | abha
# Processing Record 34 of Set 3 | hendijan
# City not found. Skipping...
# Processing Record 35 of Set 3 | birao
# Processing Record 36 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 37 of Set 3 | henties bay
# Processing Record 38 of Set 3 | east london
# Processing Record 39 of Set 3 | giaginskaya
# Processing Record 40 of Set 3 | san patricio
# Processing Record 41 of Set 3 | chenghai
# Processing Record 42 of Set 3 | saint-francois
# Processing Record 43 of Set 3 | rantauprapat
# Processing Record 44 of Set 3 | bratsk
# Processing Record 45 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 46 of Set 3 | chokurdakh
# Processing Record 47 of Set 3 | kaseda
# Processing Record 48 of Set 3 | bo
# City not found. Skipping...
# Processing Record 49 of Set 3 | bethel
# Processing Record 50 of Set 3 | upernavik
# Processing Record 1 of Set 4 | tura
# Processing Record 2 of Set 4 | acurenam
# Processing Record 3 of Set 4 | aloleng
# Processing Record 4 of Set 4 | lazarev
# Processing Record 5 of Set 4 | callaguip
# Processing Record 6 of Set 4 | llangefni
# Processing Record 7 of Set 4 | lakatoro
# Processing Record 8 of Set 4 | mar del plata
# Processing Record 9 of Set 4 | safaga
# Processing Record 10 of Set 4 | port lincoln
# Processing Record 11 of Set 4 | bambous virieux
# Processing Record 12 of Set 4 | bay saint louis
# Processing Record 13 of Set 4 | taoudenni
# Processing Record 14 of Set 4 | barrow
# Processing Record 15 of Set 4 | yeppoon
# Processing Record 16 of Set 4 | vestmannaeyjar
# Processing Record 17 of Set 4 | russell
# Processing Record 18 of Set 4 | banmo
# City not found. Skipping...
# Processing Record 19 of Set 4 | nawa
# Processing Record 20 of Set 4 | omidiyeh
# Processing Record 21 of Set 4 | ribeira grande
# Processing Record 22 of Set 4 | susehri
# Processing Record 23 of Set 4 | ahipara
# Processing Record 24 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 4 | manta
# Processing Record 26 of Set 4 | mendoza
# Processing Record 27 of Set 4 | labuan
# Processing Record 28 of Set 4 | san rafael del sur
# Processing Record 29 of Set 4 | fonte boa
# Processing Record 30 of Set 4 | ancud
# Processing Record 31 of Set 4 | yerofey pavlovich
# Processing Record 32 of Set 4 | ballybofey
# Processing Record 33 of Set 4 | tahta
# Processing Record 34 of Set 4 | carnduff
# Processing Record 35 of Set 4 | isangel
# Processing Record 36 of Set 4 | chuy
# Processing Record 37 of Set 4 | albury
# Processing Record 38 of Set 4 | brus laguna
# Processing Record 39 of Set 4 | namibe
# Processing Record 40 of Set 4 | luau
# Processing Record 41 of Set 4 | charkhi dadri
# Processing Record 42 of Set 4 | kahului
# Processing Record 43 of Set 4 | meulaboh
# Processing Record 44 of Set 4 | clovis
# Processing Record 45 of Set 4 | murgab
# Processing Record 46 of Set 4 | ambilobe
# Processing Record 47 of Set 4 | udachnyy
# Processing Record 48 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 4 | te anau
# Processing Record 50 of Set 4 | khatanga
# Processing Record 1 of Set 5 | altay
# Processing Record 2 of Set 5 | irbeyskoye
# Processing Record 3 of Set 5 | port elizabeth
# Processing Record 4 of Set 5 | port hedland
# Processing Record 5 of Set 5 | guerrero negro
# Processing Record 6 of Set 5 | de-kastri
# Processing Record 7 of Set 5 | burns lake
# Processing Record 8 of Set 5 | caravelas
# Processing Record 9 of Set 5 | vestmanna
# Processing Record 10 of Set 5 | thompson
# Processing Record 11 of Set 5 | constitucion
# Processing Record 12 of Set 5 | pokhara
# Processing Record 13 of Set 5 | morrinhos
# Processing Record 14 of Set 5 | homer
# Processing Record 15 of Set 5 | darfo
# Processing Record 16 of Set 5 | shimoda
# Processing Record 17 of Set 5 | cidreira
# Processing Record 18 of Set 5 | nuevitas
# Processing Record 19 of Set 5 | obo
# Processing Record 20 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 5 | nizhneudinsk
# Processing Record 22 of Set 5 | itoman
# Processing Record 23 of Set 5 | emborion
# Processing Record 24 of Set 5 | juneau
# Processing Record 25 of Set 5 | aklavik
# Processing Record 26 of Set 5 | kurilsk
# Processing Record 27 of Set 5 | riverton
# Processing Record 28 of Set 5 | huarmey
# Processing Record 29 of Set 5 | mitsamiouli
# Processing Record 30 of Set 5 | naples
# Processing Record 31 of Set 5 | kodiak
# Processing Record 32 of Set 5 | simao
# Processing Record 33 of Set 5 | buin
# Processing Record 34 of Set 5 | la crosse
# Processing Record 35 of Set 5 | tazovskiy
# Processing Record 36 of Set 5 | nenjiang
# Processing Record 37 of Set 5 | apaxtla
# City not found. Skipping...
# Processing Record 38 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 5 | yulara
# Processing Record 40 of Set 5 | bonfim
# Processing Record 41 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 5 | los llanos de aridane
# Processing Record 43 of Set 5 | borger
# Processing Record 44 of Set 5 | cabo san lucas
# Processing Record 45 of Set 5 | katsina
# Processing Record 46 of Set 5 | sadovo
# Processing Record 47 of Set 5 | olafsvik
# Processing Record 48 of Set 5 | tilichiki
# Processing Record 49 of Set 5 | port blair
# Processing Record 50 of Set 5 | belmonte
# Processing Record 1 of Set 6 | nago
# Processing Record 2 of Set 6 | emerald
# Processing Record 3 of Set 6 | shchebetovka
# Processing Record 4 of Set 6 | hithadhoo
# Processing Record 5 of Set 6 | alice springs
# Processing Record 6 of Set 6 | saint-fabien
# City not found. Skipping...
# Processing Record 7 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 8 of Set 6 | adre
# Processing Record 9 of Set 6 | kieta
# Processing Record 10 of Set 6 | norman wells
# Processing Record 11 of Set 6 | guaraniacu
# Processing Record 12 of Set 6 | broome
# Processing Record 13 of Set 6 | nome
# Processing Record 14 of Set 6 | grindavik
# Processing Record 15 of Set 6 | yenagoa
# Processing Record 16 of Set 6 | amapa
# Processing Record 17 of Set 6 | tuatapere
# Processing Record 18 of Set 6 | sao filipe
# Processing Record 19 of Set 6 | bata
# Processing Record 20 of Set 6 | borovichi
# Processing Record 21 of Set 6 | vila velha
# Processing Record 22 of Set 6 | baiao
# Processing Record 23 of Set 6 | bathsheba
# Processing Record 24 of Set 6 | inhambane
# Processing Record 25 of Set 6 | lorengau
# Processing Record 26 of Set 6 | dengzhou
# Processing Record 27 of Set 6 | half moon bay
# Processing Record 28 of Set 6 | krasnoselkup
# Processing Record 29 of Set 6 | yataity
# Processing Record 30 of Set 6 | zarubino
# Processing Record 31 of Set 6 | cabedelo
# Processing Record 32 of Set 6 | roald
# Processing Record 33 of Set 6 | okhotsk
# Processing Record 34 of Set 6 | ouesso
# Processing Record 35 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 6 | dawson creek
# Processing Record 37 of Set 6 | buraydah
# Processing Record 38 of Set 6 | mecca
# Processing Record 39 of Set 6 | panguipulli
# Processing Record 40 of Set 6 | gambela
# Processing Record 41 of Set 6 | marang
# Processing Record 42 of Set 6 | poum
# Processing Record 43 of Set 6 | kulebaki
# Processing Record 44 of Set 6 | pryazha
# Processing Record 45 of Set 6 | matara
# Processing Record 46 of Set 6 | sobolevo
# Processing Record 47 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 48 of Set 6 | sao luiz gonzaga
# Processing Record 49 of Set 6 | bukachacha
# Processing Record 50 of Set 6 | muravlenko
# Processing Record 1 of Set 7 | natal
# Processing Record 2 of Set 7 | kisangani
# Processing Record 3 of Set 7 | oistins
# Processing Record 4 of Set 7 | alamos
# Processing Record 5 of Set 7 | evanston
# Processing Record 6 of Set 7 | korla
# Processing Record 7 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 7 | chapais
# Processing Record 9 of Set 7 | tambopata
# Processing Record 10 of Set 7 | litoral del san juan
# City not found. Skipping...
# Processing Record 11 of Set 7 | rybachiy
# Processing Record 12 of Set 7 | berlevag
# Processing Record 13 of Set 7 | usinsk
# Processing Record 14 of Set 7 | saumur
# Processing Record 15 of Set 7 | ambulu
# Processing Record 16 of Set 7 | pochutla
# Processing Record 17 of Set 7 | megion
# Processing Record 18 of Set 7 | prieska
# Processing Record 19 of Set 7 | newport
# Processing Record 20 of Set 7 | bilibino
# Processing Record 21 of Set 7 | foam lake
# Processing Record 22 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 7 | bengkulu
# Processing Record 24 of Set 7 | taraz
# Processing Record 25 of Set 7 | longyearbyen
# Processing Record 26 of Set 7 | pontes e lacerda
# Processing Record 27 of Set 7 | da nang
# Processing Record 28 of Set 7 | henniker
# Processing Record 29 of Set 7 | kutum
# Processing Record 30 of Set 7 | ternate
# Processing Record 31 of Set 7 | touros
# Processing Record 32 of Set 7 | polunochnoye
# Processing Record 33 of Set 7 | zhuhai
# Processing Record 34 of Set 7 | san
# Processing Record 35 of Set 7 | soto la marina
# Processing Record 36 of Set 7 | kokoda
# Processing Record 37 of Set 7 | galveston
# Processing Record 38 of Set 7 | merauke
# Processing Record 39 of Set 7 | arman
# Processing Record 40 of Set 7 | paciran
# Processing Record 41 of Set 7 | sawakin
# Processing Record 42 of Set 7 | rosarito
# Processing Record 43 of Set 7 | batagay
# Processing Record 44 of Set 7 | virden
# Processing Record 45 of Set 7 | luderitz
# Processing Record 46 of Set 7 | zhigansk
# Processing Record 47 of Set 7 | yarada
# Processing Record 48 of Set 7 | kyren
# Processing Record 49 of Set 7 | haines junction
# Processing Record 50 of Set 7 | sitka
# Processing Record 1 of Set 8 | pangnirtung
# Processing Record 2 of Set 8 | plymouth
# Processing Record 3 of Set 8 | jiaozhou
# Processing Record 4 of Set 8 | terenos
# Processing Record 5 of Set 8 | sofia
# Processing Record 6 of Set 8 | porciuncula
# Processing Record 7 of Set 8 | camacha
# Processing Record 8 of Set 8 | giyani
# Processing Record 9 of Set 8 | grootfontein
# Processing Record 10 of Set 8 | khandyga
# Processing Record 11 of Set 8 | banda aceh
# Processing Record 12 of Set 8 | kembe
# Processing Record 13 of Set 8 | syracuse
# Processing Record 14 of Set 8 | abalak
# Processing Record 15 of Set 8 | san cristobal
# Processing Record 16 of Set 8 | narsaq
# Processing Record 17 of Set 8 | ampanihy
# Processing Record 18 of Set 8 | torit
# Processing Record 19 of Set 8 | la ronge
# Processing Record 20 of Set 8 | fairbanks
# Processing Record 21 of Set 8 | qaqortoq
# Processing Record 22 of Set 8 | mandaguari
# Processing Record 23 of Set 8 | kudahuvadhoo
# Processing Record 24 of Set 8 | jacareacanga
# Processing Record 25 of Set 8 | santa cruz del sur
# Processing Record 26 of Set 8 | robertsport
# Processing Record 27 of Set 8 | tezze sul brenta
# Processing Record 28 of Set 8 | fukue
# Processing Record 29 of Set 8 | jackson
# Processing Record 30 of Set 8 | srinivaspur
# Processing Record 31 of Set 8 | nueva loja
# Processing Record 32 of Set 8 | ballina
# Processing Record 33 of Set 8 | fasa
# Processing Record 34 of Set 8 | port macquarie
# Processing Record 35 of Set 8 | biloela
# Processing Record 36 of Set 8 | katsuura
# Processing Record 37 of Set 8 | bakel
# Processing Record 38 of Set 8 | saint-philippe
# Processing Record 39 of Set 8 | saint-louis
# Processing Record 40 of Set 8 | quatre cocos
# Processing Record 41 of Set 8 | gimli
# Processing Record 42 of Set 8 | tromso
# Processing Record 43 of Set 8 | anadyr
# Processing Record 44 of Set 8 | kongoussi
# Processing Record 45 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 46 of Set 8 | shishou
# Processing Record 47 of Set 8 | kilmez
# City not found. Skipping...
# Processing Record 48 of Set 8 | hambantota
# Processing Record 49 of Set 8 | klaebu
# Processing Record 50 of Set 8 | ponta do sol
# Processing Record 1 of Set 9 | port hardy
# Processing Record 2 of Set 9 | rapar
# Processing Record 3 of Set 9 | ahuimanu
# Processing Record 4 of Set 9 | heishan
# Processing Record 5 of Set 9 | hakkari
# Processing Record 6 of Set 9 | acajutla
# Processing Record 7 of Set 9 | gallup
# Processing Record 8 of Set 9 | huejucar
# Processing Record 9 of Set 9 | sioux lookout
# Processing Record 10 of Set 9 | tianpeng
# Processing Record 11 of Set 9 | konongo
# Processing Record 12 of Set 9 | bulembu
# Processing Record 13 of Set 9 | mayskiy
# Processing Record 14 of Set 9 | dakar
# Processing Record 15 of Set 9 | svetlaya
# Processing Record 16 of Set 9 | finsterwalde
# Processing Record 17 of Set 9 | kamenka
# Processing Record 18 of Set 9 | cam ranh
# Processing Record 19 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 9 | akureyri
# Processing Record 21 of Set 9 | ochakiv
# Processing Record 22 of Set 9 | vanimo
# Processing Record 23 of Set 9 | deputatskiy
# Processing Record 24 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 9 | togur
# Processing Record 26 of Set 9 | anchorage
# Processing Record 27 of Set 9 | progreso
# Processing Record 28 of Set 9 | kirishi
# Processing Record 29 of Set 9 | sur
# Processing Record 30 of Set 9 | paredon
# Processing Record 31 of Set 9 | santa isabel do rio negro
# Processing Record 32 of Set 9 | vardo
# Processing Record 33 of Set 9 | marsa matruh
# Processing Record 34 of Set 9 | pakxan
# Processing Record 35 of Set 9 | hualmay
# Processing Record 36 of Set 9 | nouadhibou
# Processing Record 37 of Set 9 | hauterive
# Processing Record 38 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 39 of Set 9 | aitape
# Processing Record 40 of Set 9 | rio grande
# Processing Record 41 of Set 9 | otavi
# Processing Record 42 of Set 9 | buenos aires
# Processing Record 43 of Set 9 | saint-paul
# Processing Record 44 of Set 9 | nazare
# Processing Record 45 of Set 9 | atambua
# Processing Record 46 of Set 9 | shumikha
# Processing Record 47 of Set 9 | rockland
# Processing Record 48 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 49 of Set 9 | boa esperanca
# Processing Record 50 of Set 9 | archidona
# Processing Record 1 of Set 10 | manono
# Processing Record 2 of Set 10 | calabozo
# Processing Record 3 of Set 10 | waingapu
# Processing Record 4 of Set 10 | kifri
# Processing Record 5 of Set 10 | sicamous
# Processing Record 6 of Set 10 | tommot
# Processing Record 7 of Set 10 | clearwater
# Processing Record 8 of Set 10 | schwerin
# Processing Record 9 of Set 10 | wewak
# Processing Record 10 of Set 10 | zelenogorskiy
# Processing Record 11 of Set 10 | port moresby
# Processing Record 12 of Set 10 | kokopo
# Processing Record 13 of Set 10 | adwa
# Processing Record 14 of Set 10 | bridlington
# Processing Record 15 of Set 10 | sorong
# Processing Record 16 of Set 10 | marsh harbour
# Processing Record 17 of Set 10 | acarau
# Processing Record 18 of Set 10 | ewa beach
# Processing Record 19 of Set 10 | abu dhabi
# Processing Record 20 of Set 10 | boralday
# Processing Record 21 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 10 | ouango
# Processing Record 23 of Set 10 | upington
# Processing Record 24 of Set 10 | vagur
# Processing Record 25 of Set 10 | mae hong son
# Processing Record 26 of Set 10 | boa vista
# Processing Record 27 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 10 | pisco
# Processing Record 29 of Set 10 | kruisfontein
# Processing Record 30 of Set 10 | chicama
# Processing Record 31 of Set 10 | aracati
# Processing Record 32 of Set 10 | roswell
# Processing Record 33 of Set 10 | mahebourg
# Processing Record 34 of Set 10 | vuktyl
# Processing Record 35 of Set 10 | matagami
# Processing Record 36 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 10 | maniitsoq
# Processing Record 38 of Set 10 | patrocinio
# Processing Record 39 of Set 10 | harqalah
# Processing Record 40 of Set 10 | seoul
# Processing Record 41 of Set 10 | goderich
# Processing Record 42 of Set 10 | paranhos
# Processing Record 43 of Set 10 | denpasar
# Processing Record 44 of Set 10 | port shepstone
# Processing Record 45 of Set 10 | tezu
# Processing Record 46 of Set 10 | rosetta
# Processing Record 47 of Set 10 | roros
# Processing Record 48 of Set 10 | zhezkazgan
# Processing Record 49 of Set 10 | saint helens
# Processing Record 50 of Set 10 | vieste
# Processing Record 1 of Set 11 | sidi ali
# Processing Record 2 of Set 11 | rio gallegos
# Processing Record 3 of Set 11 | slave lake
# Processing Record 4 of Set 11 | wanganui
# Processing Record 5 of Set 11 | estepa
# Processing Record 6 of Set 11 | fulitun
# City not found. Skipping...
# Processing Record 7 of Set 11 | kaitong
# Processing Record 8 of Set 11 | camocim
# Processing Record 9 of Set 11 | chamrajnagar
# Processing Record 10 of Set 11 | mlandizi
# Processing Record 11 of Set 11 | mega
# Processing Record 12 of Set 11 | catamarca
# Processing Record 13 of Set 11 | yaan
# Processing Record 14 of Set 11 | lahaina
# Processing Record 15 of Set 11 | vaitape
# Processing Record 16 of Set 11 | margate
# Processing Record 17 of Set 11 | perth
# Processing Record 18 of Set 11 | malakal
# Processing Record 19 of Set 11 | saintes
# Processing Record 20 of Set 11 | limbang
# Processing Record 21 of Set 11 | shumskiy
# Processing Record 22 of Set 11 | shellbrook
# Processing Record 23 of Set 11 | bellevue
# Processing Record 24 of Set 11 | great yarmouth
# Processing Record 25 of Set 11 | saurimo
# Processing Record 26 of Set 11 | klaksvik
# Processing Record 27 of Set 11 | walvis bay
# Processing Record 28 of Set 11 | yeniseysk
# Processing Record 29 of Set 11 | tukrah
# Processing Record 30 of Set 11 | flin flon
# Processing Record 31 of Set 11 | poli
# Processing Record 32 of Set 11 | quelimane
# Processing Record 33 of Set 11 | yumen
# Processing Record 34 of Set 11 | lowestoft
# Processing Record 35 of Set 11 | angoche
# Processing Record 36 of Set 11 | namatanai
# Processing Record 37 of Set 11 | chipinge
# Processing Record 38 of Set 11 | bonavista
# Processing Record 39 of Set 11 | daloa
# Processing Record 40 of Set 11 | tiznit
# Processing Record 41 of Set 11 | coihaique
# Processing Record 42 of Set 11 | gerash
# Processing Record 43 of Set 11 | karnal
# Processing Record 44 of Set 11 | saint-augustin
# Processing Record 45 of Set 11 | geresk
# City not found. Skipping...
# Processing Record 46 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 11 | dzhebariki-khaya
# Processing Record 48 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 49 of Set 11 | beloha
# Processing Record 50 of Set 11 | masallatah
# Processing Record 1 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 2 of Set 12 | ucluelet
# Processing Record 3 of Set 12 | kununurra
# Processing Record 4 of Set 12 | tual
# Processing Record 5 of Set 12 | cabo rojo
# Processing Record 6 of Set 12 | berdigestyakh
# Processing Record 7 of Set 12 | lovozero
# Processing Record 8 of Set 12 | sacel
# Processing Record 9 of Set 12 | serra talhada
# Processing Record 10 of Set 12 | senovo
# Processing Record 11 of Set 12 | terrace
# Processing Record 12 of Set 12 | axim
# Processing Record 13 of Set 12 | yar-sale
# Processing Record 14 of Set 12 | gizo
# Processing Record 15 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 16 of Set 12 | willmar
# Processing Record 17 of Set 12 | bubaque
# Processing Record 18 of Set 12 | hammerfest
# Processing Record 19 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 20 of Set 12 | havoysund
# Processing Record 21 of Set 12 | dingle
# Processing Record 22 of Set 12 | athens
# Processing Record 23 of Set 12 | agadez
# Processing Record 24 of Set 12 | pauini
# Processing Record 25 of Set 12 | bud
# Processing Record 26 of Set 12 | vossevangen
# Processing Record 27 of Set 12 | solwezi
# Processing Record 28 of Set 12 | pandan
# Processing Record 29 of Set 12 | vitim
# Processing Record 30 of Set 12 | quzhou
# Processing Record 31 of Set 12 | lukovetskiy
# Processing Record 32 of Set 12 | zhoucheng
# Processing Record 33 of Set 12 | kendari
# Processing Record 34 of Set 12 | manguiring
# City not found. Skipping...
# Processing Record 35 of Set 12 | gongzhuling
# Processing Record 36 of Set 12 | kysyl-syr
# Processing Record 37 of Set 12 | yankton
# Processing Record 38 of Set 12 | orlik
# Processing Record 39 of Set 12 | norrtalje
# Processing Record 40 of Set 12 | gabu
# Processing Record 41 of Set 12 | tevriz
# Processing Record 42 of Set 12 | lasa
# Processing Record 43 of Set 12 | mangai
# Processing Record 44 of Set 12 | basco
# Processing Record 45 of Set 12 | manokwari
# Processing Record 46 of Set 12 | horasan
# Processing Record 47 of Set 12 | auki
# Processing Record 48 of Set 12 | alexandria
# Processing Record 49 of Set 12 | ust-nera
# Processing Record 50 of Set 12 | the valley
# Processing Record 1 of Set 13 | yanam
# Processing Record 2 of Set 13 | taft
# Processing Record 3 of Set 13 | north bend
# Processing Record 4 of Set 13 | mananara
# Processing Record 5 of Set 13 | san francisco
# Processing Record 6 of Set 13 | palana
# Processing Record 7 of Set 13 | zolotinka
# City not found. Skipping...
# Processing Record 8 of Set 13 | alcudia
# Processing Record 9 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 13 | zhangjiakou
# Processing Record 11 of Set 13 | emirdag
# Processing Record 12 of Set 13 | oussouye
# Processing Record 13 of Set 13 | bontang
# Processing Record 14 of Set 13 | wajima
# Processing Record 15 of Set 13 | bishop auckland
# Processing Record 16 of Set 13 | katherine
# Processing Record 17 of Set 13 | sakakah
# Processing Record 18 of Set 13 | houma
# Processing Record 19 of Set 13 | geraldton
# Processing Record 20 of Set 13 | selizharovo
# Processing Record 21 of Set 13 | lipin bor
# Processing Record 22 of Set 13 | sorland
# Processing Record 23 of Set 13 | kyra
# Processing Record 24 of Set 13 | mazamari
# Processing Record 25 of Set 13 | beroroha
# Processing Record 26 of Set 13 | evensk
# Processing Record 27 of Set 13 | kenitra
# Processing Record 28 of Set 13 | port augusta
# Processing Record 29 of Set 13 | bilma
# Processing Record 30 of Set 13 | aswan
# Processing Record 31 of Set 13 | san martin
# Processing Record 32 of Set 13 | lata
# Processing Record 33 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 34 of Set 13 | pilao arcado
# City not found. Skipping...
# Processing Record 35 of Set 13 | belyy yar
# Processing Record 36 of Set 13 | hofn
# Processing Record 37 of Set 13 | tupik
# Processing Record 38 of Set 13 | atessa
# Processing Record 39 of Set 13 | labrea
# Processing Record 40 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 13 | basoko
# Processing Record 43 of Set 13 | paamiut
# Processing Record 44 of Set 13 | karema
# Processing Record 45 of Set 13 | brenham
# Processing Record 46 of Set 13 | varna
# Processing Record 47 of Set 13 | colesberg
# Processing Record 48 of Set 13 | gobabis
# Processing Record 49 of Set 13 | lujiang
# Processing Record 50 of Set 13 | tombouctou
# Processing Record 1 of Set 14 | key west
# Processing Record 2 of Set 14 | nechanice
# Processing Record 3 of Set 14 | saint anthony
# Processing Record 4 of Set 14 | pacifica
# Processing Record 5 of Set 14 | humboldt
# Processing Record 6 of Set 14 | khudumelapye
# Processing Record 7 of Set 14 | sal rei
# Processing Record 8 of Set 14 | avera
# Processing Record 9 of Set 14 | nyuksenitsa
# Processing Record 10 of Set 14 | komsomolskiy
# Processing Record 11 of Set 14 | segezha
# Processing Record 12 of Set 14 | pinega
# Processing Record 13 of Set 14 | kungurtug
# Processing Record 14 of Set 14 | kloulklubed
# Processing Record 15 of Set 14 | zheleznodorozhnyy
# Processing Record 16 of Set 14 | mayo
# Processing Record 17 of Set 14 | isla vista
# Processing Record 18 of Set 14 | puerto el triunfo
# Processing Record 19 of Set 14 | zhitikara
# City not found. Skipping...
# Processing Record 20 of Set 14 | mandurah
# Processing Record 21 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 14 | nizwa
# Processing Record 23 of Set 14 | amarwara
# Processing Record 24 of Set 14 | lerwick
# Processing Record 25 of Set 14 | huntsville
# Processing Record 26 of Set 14 | kibala
# Processing Record 27 of Set 14 | qui nhon
# Processing Record 28 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 29 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 14 | san quintin
# Processing Record 31 of Set 14 | carutapera
# Processing Record 32 of Set 14 | minggang
# Processing Record 33 of Set 14 | bhakkar
# Processing Record 34 of Set 14 | cockburn town
# Processing Record 35 of Set 14 | brae
# Processing Record 36 of Set 14 | katobu
# Processing Record 37 of Set 14 | veraval
# Processing Record 38 of Set 14 | faya
# Processing Record 39 of Set 14 | finote selam
# Processing Record 40 of Set 14 | solnechnyy
# Processing Record 41 of Set 14 | aksu
# Processing Record 42 of Set 14 | maceio
# Processing Record 43 of Set 14 | udimskiy
# Processing Record 44 of Set 14 | misratah
# Processing Record 45 of Set 14 | leh
# Processing Record 46 of Set 14 | nhulunbuy
# Processing Record 47 of Set 14 | telchac
# Processing Record 48 of Set 14 | tabasco
# Processing Record 49 of Set 14 | jega
# Processing Record 50 of Set 14 | taiyuan
# Processing Record 1 of Set 15 | kurumkan
# Processing Record 2 of Set 15 | victor harbor
# Processing Record 3 of Set 15 | boyolangu
# Processing Record 4 of Set 15 | igrim
# Processing Record 5 of Set 15 | ginda
# Processing Record 6 of Set 15 | eyl
# Processing Record 7 of Set 15 | bac
# Processing Record 8 of Set 15 | raudeberg
# Processing Record 9 of Set 15 | yamada
# Processing Record 10 of Set 15 | port hawkesbury
# Processing Record 11 of Set 15 | ekibastuz
# Processing Record 12 of Set 15 | ondjiva
# Processing Record 13 of Set 15 | las guacamayas
# Processing Record 14 of Set 15 | uralskiy
# City not found. Skipping...
# Processing Record 15 of Set 15 | matamoros
# Processing Record 16 of Set 15 | stykkisholmur
# Processing Record 17 of Set 15 | ust-kulom
# Processing Record 18 of Set 15 | dzaoudzi
# Processing Record 19 of Set 15 | majene
# Processing Record 20 of Set 15 | kathmandu
# Processing Record 21 of Set 15 | vredendal
# Processing Record 22 of Set 15 | verkhnevilyuysk
# Processing Record 23 of Set 15 | vegreville
# Processing Record 24 of Set 15 | lazaro cardenas
# Processing Record 25 of Set 15 | padang
# Processing Record 26 of Set 15 | kpandae
# Processing Record 27 of Set 15 | kalemie
# Processing Record 28 of Set 15 | iguape
# Processing Record 29 of Set 15 | hamilton
# Processing Record 30 of Set 15 | new waterford
# Processing Record 31 of Set 15 | galesong
# Processing Record 32 of Set 15 | shubarkuduk
# Processing Record 33 of Set 15 | marathon
# Processing Record 34 of Set 15 | urucara
# Processing Record 35 of Set 15 | vilhena
# Processing Record 36 of Set 15 | nara
# Processing Record 37 of Set 15 | khakhea
# Processing Record 38 of Set 15 | husavik
# Processing Record 39 of Set 15 | hirara
# Processing Record 40 of Set 15 | kozan
# Processing Record 41 of Set 15 | shchelyayur
# City not found. Skipping...
# Processing Record 42 of Set 15 | santiago del estero
# Processing Record 43 of Set 15 | vaasa
# Processing Record 44 of Set 15 | humaita
# Processing Record 45 of Set 15 | calvinia
# Processing Record 46 of Set 15 | duluth
# Processing Record 47 of Set 15 | amposta
# Processing Record 48 of Set 15 | necochea
# Processing Record 49 of Set 15 | gumdag
# Processing Record 50 of Set 15 | lumberton
# Processing Record 1 of Set 16 | mana
# Processing Record 2 of Set 16 | saiha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 696

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          biak  -0.9131  122.8766     81.43        71         100
# 1       rikitea -23.1203 -134.9692     78.73        77          84
# 2    bredasdorp -34.5322   20.0403     72.84        63         100
# 3        rawson -43.3002  -65.1023     61.05        89         100
# 4    whitehorse  60.7161 -135.0538      7.57        85          75
# 5        dikson  73.5069   80.5464    -24.12        98         100
# 6      bathurst -33.4166  149.5806     92.71        38          59
# 7  punta arenas -53.1500  -70.9167     44.71        93          40
# 8        ixtapa  20.7000 -105.2000     69.22        84           1
# 9       salalah  17.0151   54.0924     78.89        61           0
#
#    Wind Speed Current Description Country
# 0        3.56     overcast clouds      ID
# 1       14.65       broken clouds      PF
# 2        5.55     overcast clouds      ZA
# 3        8.95          light rain      AR
# 4       16.11       broken clouds      CA
# 5        5.97     overcast clouds      RU
# 6        5.70       broken clouds      AU
# 7        6.91    scattered clouds      CL
# 8        1.01           clear sky      MX
# 9        2.30           clear sky      OM

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          biak      ID  -0.9131  122.8766     81.43        71         100
# 1       rikitea      PF -23.1203 -134.9692     78.73        77          84
# 2    bredasdorp      ZA -34.5322   20.0403     72.84        63         100
# 3        rawson      AR -43.3002  -65.1023     61.05        89         100
# 4    whitehorse      CA  60.7161 -135.0538      7.57        85          75
# 5        dikson      RU  73.5069   80.5464    -24.12        98         100
# 6      bathurst      AU -33.4166  149.5806     92.71        38          59
# 7  punta arenas      CL -53.1500  -70.9167     44.71        93          40
# 8        ixtapa      MX  20.7000 -105.2000     69.22        84           1
# 9       salalah      OM  17.0151   54.0924     78.89        61           0
#
#    Wind Speed Current Description
# 0        3.56     overcast clouds
# 1       14.65       broken clouds
# 2        5.55     overcast clouds
# 3        8.95          light rain
# 4       16.11       broken clouds
# 5        5.97     overcast clouds
# 6        5.70       broken clouds
# 7        6.91    scattered clouds
# 8        1.01           clear sky
# 9        2.30           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file_name = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file_name, index_label='City_ID')
